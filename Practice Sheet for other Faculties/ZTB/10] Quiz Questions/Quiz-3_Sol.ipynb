# %%
cars = ('SY19102','DH0790','DH0000','CH0416')
d1 = {}
for i in cars:
  year = '20'+i[2]+i[3]
  d1['Year'] = year
  if i[0]+i[1] == "DH":
    d1["Area"]="Dhaka"
  elif i[0]+i[1]=='SY':
    d1['Area']='Sylhet'
  elif i[0]+i[1]=='CH':
    d1['Area']='Chittagong'
  d1['Registration Fee']=int(i[4:])*950
  print(d1)
  d1={}
# Out:
# {'Year': '2019', 'Area': 'Sylhet', 'Registration Fee': 96900}
# {'Year': '2007', 'Area': 'Dhaka', 'Registration Fee': 85500}
# {'Year': '2000', 'Area': 'Dhaka', 'Registration Fee': 0}
# {'Year': '2004', 'Area': 'Chittagong', 'Registration Fee': 15200}

# %%
student_id = ('220137','19901101','210288','200391')
q = {}
x = ''
for i in student_id:
  q['Enrollment year']='20'+i[0]+i[1]
  if i[2]=='0' and i[3]=='1':
    q['Department']='CSE'
  elif i[2]=='0' and i[3]=='2': 
    q['Department']='CS'
  elif i[2]=='0' and i[3]=='3':
    q['Department']='MNS'
  for j in range(4,len(i)):
    x+=i[j]
  fee = (int(x))*6600
  q['course fee']=fee
  print(q)
  q = {}
# Out:
# {'Enrollment year': '2022', 'Department': 'CSE', 'course fee': 244200}
# {'Enrollment year': '2019', 'course fee': 2449266600}
# {'Enrollment year': '2021', 'Department': 'CS', 'course fee': 244927240800}
# {'Enrollment year': '2020', 'Department': 'MNS', 'course fee': 24492724680600}

# %%
dict1 = {}
dict1['a','b']=1,2
print(dict1)
# Out:
# {('a', 'b'): (1, 2)}

# %%
class A: 
  temp = 3
  def __init__(self):
    self.sum = 0
    self.y = 0
    self.y = A.temp - 1
    self.sum = A.temp + 2
    A.temp -= 2
  
  def methodA(self, m, n):
    x = 0
    n[0] += 1
    self.y = self.y + m + A.temp
    A.temp += 1
    x = x + 2 + n[0]
    n[0] = self.sum + 2
    print(f"{x} {self.y} {self.sum}")
    return x
 
class B(A):
  x = 1
  def __init__(self, b = None):
    super().__init__()
    self.sum = 2
    self.x+=1
    if b == None:  
      self.y = self.temp + 1    
      B.x = 3 + A.temp + self.x
      A.temp -= 3
    else:
      self.sum = self.sum + self.sum
      B.x = b.x + self.x


  def methodB(self, m, n):
    y = [0]
    self.y = y[0] + self.y + m
    B.x = self.y + 2 +  self.temp - n
    self.x += self.methodA(self.x, y)
    self.sum = self.x + y[0] + self.sum
    print(f"{self.x} {y[0]} {self.sum}")

x = [23]
a1 = A()
b1 = B()
b2 = B(b1)
a1.methodA(1,x)
b1.methodB(3,2)
a1.methodA(1,x)
# Out:
# 26 -3 5
# 3 0 2
# 5 4 11
# 10 -6 5
# 10
